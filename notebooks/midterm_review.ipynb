# %% [markdown]
# # # Elements of Data Science: A First Course
#
# # COMS W4995 008 2017 3
#
#
# ## Midterm Review

# %% [markdown]
# This is intended as a guide and may not be inclusive.
#
# Material considered fair for the exam is anything from class, the slides or the readings from the PDSH book.
#
# Note sheet allowed: 1 8x11in paper with handwritten notes

# %% [markdown]
# - Introduction to Data Science problems and tools
#     - Data Science workflow
#     - virtual environments
#     - Ipython Notebook
#
#
# - Data Processing and Delivery: ETL and API
#     - data type
#     - dataset structure
#     - numpy
#         - arrays
#         - matrices
#         - indexing
#         - ufuncs
#     - pandas
#         - series
#         - dataframes
#         - data inspection
#         - indexing
#         - grouping
#         - load from csv
#     - transforming data
#         - missing values/imputing
#         - concatinate, append and join
#         - setting indices
#         - setting columns
#         - aggregation and summarization
#         - dealing with duplicates
#         - creating dummies
#         - normalizing/standardizing columns
#     - API
#         - what is it?
#         - why would we want to make one?
#         - (no questions on flask)
#
#
# - Data Exploration and Visualization
#     - assert
#     - pivot tables
#     - single variable statistics
#         - mean
#         - variance
#         - quantiles
#     - plotting (why and how)
#         - histograms
#         - box plots
#         - scatter plots
#     - correlation
#
#
#
# - Data Cleaning and Management
#     - outliers
#         - causes
#         - detection
#         - dealing with
#     - binning
#     - structured vs unstructured data
#     - relational vs nosql databases
#         - basic sql commands
#         - know about sqlalchemy but not commands
#         - (no mongo commands)
#
#
# - Classification and Regression
#     - supervised learning
#     - sklearn model commands
#     - (know models conceptually)
#     - (know differences between models)
#     - regression
#         - simple linear regression
#         - polynomial regression
#         - multivariate regression
#     - (know about statsmodels, but not specifics)
#     - classification
#         - k Nearest Neighbor
#         - logistic regression
#         - naive bayes
#         - decision trees
#         - (know what an ensemble is)
#             - random forest
#         - svm (very generally)
#         - neural networks (very generally)
#
#
# - Feature Engineering and Application: Natural Language Processing
#     - pipelines
#     - zscore/scaling/normalizing
#     - dummy variables/one-hot-encoding
#     - imputing/mean/median
#     - natural language processing
#          - document, corpus
#          - tokenization
#          - bag of words
#          - term/document frequency
#          - tf-idf
#          - n-grams
#
#
#
# - NOT ON THE EXAM
#     - material from lecture 7
#     - eg. model evaluation, train/test, overfitting, regularization
